# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load best.pt
model = YOLO("best.pt")

# Run inference on 'bus.jpg' with arguments
model.predict("test/images", save=True, conf=0.15)
